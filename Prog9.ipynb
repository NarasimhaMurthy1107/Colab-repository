# %% [markdown]
# <a href="https://colab.research.google.com/github/NarasimhaMurthy1107/Colab-repository/blob/main/Prog9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s1 = 'Hello'
print(type(s1))
p = [1,3,4]
print(type(p))
f ={69,86,56}
print(type(f))
tup = (45,63,67)
print(type(tup))
r=range(99,1054)
print(type(r))
# Out:
# <class 'str'>
# <class 'list'>
# <class 'set'>
# <class 'tuple'>
# <class 'range'>
