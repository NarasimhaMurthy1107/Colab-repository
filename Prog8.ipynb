# %% [markdown]
# <a href="https://colab.research.google.com/github/NarasimhaMurthy1107/Colab-repository/blob/main/Prog8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 26
b = 34
print ("a+b=",a+b)
print ("a*b=",a*b)
print ("a/b=",a/b)
print("a//b",a//b)
print ("a**b",a**b)
print(a > b)
print( a == b)
print (a != b)
# Out:
# a+b= 60
# a*b= 884
# a/b= 0.7647058823529411
# a//b 0
# a**b 1285564381113498051199127603629788201662311038976
# False
# False
# True
