# %% [markdown]
# <a href="https://colab.research.google.com/github/NarasimhaMurthy1107/Colab-repository/blob/main/Prog10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
total = num1 + num2
print("The sum is:", total)
# Out:
# Enter first number: 34
# Enter second number: 43
# The sum is: 77.0
