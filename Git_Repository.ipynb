# %% [markdown]
# <a href="https://colab.research.google.com/github/NarasimhaMurthy1107/Colab-repository/blob/main/Git_Repository.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROGRAM 1

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# PROGRAM 2

# %%
a=2
b=7
c=a+b
print(c)
# Out:
# 9

# %% [markdown]
# PROGRAM 3

# %%
n = 11
for i in range(2, n):
    if n % i == 0:
        print("Not Prime")
        break
else:
    print("Prime")
# Out:
# Prime

# %% [markdown]
# PROGRAM 4

# %%
def num_factors_bruteforce(n):
    count=0
    for i in range (1,n+1):
        if(n%i==0):
           count = count+1
    return count
    n=36
print(num_factors_bruteforce(n))
# Out:
# 2

# %% [markdown]
# PROGRAM 5

# %%
def is_valid(s):
    stack = []
    mapping = {')':'(', ']':'[', '}':'{'}
    for ch in s:
        if ch in mapping.values():  # opening bracket
            stack.append(ch)
        elif ch in mapping:  # closing bracket
            if not stack or stack[-1] != mapping[ch]:
                return False
            stack.pop()
    return not stack

print(is_valid("(){}[]"))  # True
print(is_valid("([)]"))    # False
# Out:
# True
# False

# %% [markdown]
# PROGRAM 6

# %%
def factorial(n):
    fact = 1
    for i in range(2,n+1):
        fact*=i
    return fact
    def ncr(n,r):
        return(factorial(n)//factorial(r)*factorial(n-r))
    def binomial_coefficients(n):
        return([ncr(n,r)for r in range(n+1)])
        n=10
        print(binomial_coefficients(n))

# %% [markdown]
# PROGRAM 7

# %%
import random

n = random.randint(1, 100)
while (g := int(input("Guess (1‑100): "))) != n:
    print("Higher " if g < n else "Lower ")
print(" Correct!")
# Out:
# Guess (1‑100): 3
# Higher
# Guess (1‑100): 4
# Higher
# Guess (1‑100): 68
# Lower
# Guess (1‑100): 50
# Lower
# Guess (1‑100): 25
# Higher
# Guess (1‑100): 45
# Higher
# Guess (1‑100): 47
# Higher
# Guess (1‑100): 49
# Lower
# Guess (1‑100): 48
#  Correct!

# %% [markdown]
# PROGRAM 8

# %%
a = 26
b = 34
print ("a+b=",a+b)
print ("a*b=",a*b)
print ("a/b=",a/b)
print("a//b",a//b)
print ("a**b",a**b)
print(a > b)
print( a == b)
print (a != b)
# Out:
# a+b= 60
# a*b= 884
# a/b= 0.7647058823529411
# a//b 0
# a**b 1285564381113498051199127603629788201662311038976
# False
# False
# True

# %% [markdown]
# PROGRAM 9

# %%
s1 = 'Hello'
print(type(s1))
p = [1,3,4]
print(type(p))
f ={69,86,56}
print(type(f))
tup = (45,63,67)
print(type(tup))
r=range(99,1054)
print(type(r))
# Out:
# <class 'str'>
# <class 'list'>
# <class 'set'>
# <class 'tuple'>
# <class 'range'>

# %% [markdown]
# PROGRAM 10

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
total = num1 + num2
print("The sum is:", total)
# Out:
# Enter first number: 25
# Enter second number: 54
# The sum is: 79.0

# %% [markdown]
# PROGRAM 11

# %%
table = {
    ("A", "Clean"): "MoveRight",
    ("A", "Dirty"): "Suck",
    ("B", "Clean"): "MoveLeft",
    ("B", "Dirty"): "Suck",
}

percept = [("A", "Dirty"), ("A", "Clean"), ("B", "Dirty")]
agent_table = {}

def lookup(percept, table):
    action = table.get(percept)
    return action

for p in percept:
    action = lookup(p, table)
    agent_table[p] = action
print(agent_table)
# Out:
# {('A', 'Dirty'): 'Suck', ('A', 'Clean'): 'MoveRight', ('B', 'Dirty'): 'Suck'}

# %% [markdown]
# PROGRAM 12

# %%
import random

class TicTacToe:
    def __init__(self):

        self.board = [" " for _ in range(9)]
        self.human_player = "O"
        self.ai_player = "X"

    def print_board(self):

        for i in range(0, 9, 3):
            print(f"{self.board[i]} | {self.board[i+1]} | {self.board[i+2]}")
            if i < 6:
                print("---------")

    def available_moves(self):

        return [i for i, spot in enumerate(self.board) if spot == " "]

    def make_move(self, position, player):

        if self.board[position] == " ":
            self.board[position] = player
            return True
        return False

    def is_board_full(self):

        return " " not in self.board

    def check_winner(self):

        for i in range(0, 9, 3):
            if self.board[i] == self.board[i + 1] == self.board[i + 2] != " ":
                return self.board[i]


        for i in range(3):
            if self.board[i] == self.board[i + 3] == self.board[i + 6] != " ":
                return self.board[i]


        if self.board[0] == self.board[4] == self.board[8] != " ":
            return self.board[0]
        if self.board[2] == self.board[4] == self.board[6] != " ":
            return self.board[2]

        return None

    def game_over(self):

        return self.check_winner() is not None or self.is_board_full()

    def minimax(self, depth, is_maximizing):

        winner = self.check_winner()
        if winner == self.ai_player:
            return 1
        if winner == self.human_player:
            return -1
        if self.is_board_full():
            return 0

        if is_maximizing:
            best_score = float("-inf")
            for move in self.available_moves():
                self.board[move] = self.ai_player
                score = self.minimax(depth + 1, False)
                self.board[move] = " "
                best_score = max(score, best_score)
            return best_score
        else:
            best_score = float("inf")
            for move in self.available_moves():
                self.board[move] = self.human_player
                score = self.minimax(depth + 1, True)
                self.board[move] = " "
                best_score = min(score, best_score)
            return best_score

    def get_best_move(self):

        best_score = float("-inf")
        best_move = None

        for move in self.available_moves():
            self.board[move] = self.ai_player
            score = self.minimax(0, False)
            self.board[move] = " "
            if score > best_score:
                best_score = score
                best_move = move
        return best_move

    def play_game(self):

        print("Welcome to Tic Tac Toe!")
        print("You are 'O' and the AI is 'X'")
        print("Enter positions (0-8) as shown below:")
        print("0 | 1 | 2")
        print("---------")
        print("3 | 4 | 5")
        print("---------")
        print("6 | 7 | 8")
        print("\n")

        ai_turn = random.choice([True, False])

        while not self.game_over():
            self.print_board()
            if ai_turn:
                print("\nAI's turn...")
                move = self.get_best_move()
                self.make_move(move, self.ai_player)
            else:
                while True:
                    try:
                        move = int(input("\nYour turn (0-8): "))
                        if 0 <= move <= 8 and self.make_move(move, self.human_player):
                            break
                        else:
                            print("Invalid move! Try again.")
                    except ValueError:
                        print("Please enter a number between 0 and 8!")
            ai_turn = not ai_turn


        self.print_board()
        winner = self.check_winner()
        if winner == self.ai_player:
            print("\nAI wins!")
        elif winner == self.human_player:
            print("\nYou win!")
        else:
            print("\nIt's a tie!")


if __name__ == "__main__":
    game = TicTacToe()
    game.play_game()
# Out:
# Welcome to Tic Tac Toe!
# You are 'O' and the AI is 'X'
# Enter positions (0-8) as shown below:
# 0 | 1 | 2
# ---------
# 3 | 4 | 5
# ---------
# 6 | 7 | 8
#
#
#   |   |
# ---------
#   |   |
# ---------
#   |   |
#
# AI's turn...
# X |   |
# ---------
#   |   |
# ---------
#   |   |
#
# Your turn (0-8): 0
# Invalid move! Try again.
#
# Your turn (0-8): 8
# X |   |
# ---------
#   |   |
# ---------
#   |   | O
#
# AI's turn...
# X |   | X
# ---------
#   |   |
# ---------
#   |   | O
#
# Your turn (0-8): 4
# X |   | X
# ---------
#   | O |
# ---------
#   |   | O
#
# AI's turn...
# X | X | X
# ---------
#   | O |
# ---------
#   |   | O
#
# AI wins!

# %% [markdown]
# PROGRAM 13

# %%
x=10
y=6.7
z = "gitam"
flag = True
print(type(x))
print(type(y))
print(type(z))
print(type(flag))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
