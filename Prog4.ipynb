# %% [markdown]
# <a href="https://colab.research.google.com/github/NarasimhaMurthy1107/Colab-repository/blob/main/Prog4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def num_factors_bruteforce(n):
    count=0
    for i in range (1,n+1):
        if(n%i==0):
           count = count+1
    return count
    n=36
print(num_factors_bruteforce(n))
# Out:
# 2
