# %% [markdown]
# <a href="https://colab.research.google.com/github/NarasimhaMurthy1107/Colab-repository/blob/main/Prog7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

n = random.randint(1, 100)
while (g := int(input("Guess (1‑100): "))) != n:
    print("Higher " if g < n else "Lower ")
print(" Correct!")
# Out:
# Guess (1‑100): 34
# Lower
